# %%
import pandas as pd

# %%
jan = pd.read_csv('DEMACRO/2019/jan2019.csv', sep = ';')
fev = pd.read_csv('DEMACRO/2019/fev2019.csv', sep = ';')
mar = pd.read_csv('DEMACRO/2019/mar2019.csv', sep = ';')
abr = pd.read_csv('DEMACRO/2019/abr2019.csv', sep = ';')
mai = pd.read_csv('DEMACRO/2019/mai2019.csv', sep = ';')
jun = pd.read_csv('DEMACRO/2019/jun2019.csv', sep = ';')
jul = pd.read_csv('DEMACRO/2019/jul2019.csv', sep = ';')
ago = pd.read_csv('DEMACRO/2019/ago2019.csv', sep = ';')
sete = pd.read_csv('DEMACRO/2019/set2019.csv', sep = ';')
out = pd.read_csv('DEMACRO/2019/out2019.csv', sep = ';')
#nov = pd.read_csv('DEMACRO/2019/nov2019.csv', sep = ';')
dez = pd.read_csv('DEMACRO/2019/dez2019.csv', sep = ';')

# %%
dez.head(10)
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2019  1494541   1494541/2019  01/12/2019 00:45:32  01/12/2019 00:45:35
# 1    2019  1494580   1494580/2019  01/12/2019 01:43:09  01/12/2019 01:42:46
# 2    2019  1494595   1494595/2019  01/12/2019 01:51:04  01/12/2019 01:50:31
# 3    2019     4219      4219/2019  01/12/2019 02:37:51  01/12/2019 02:56:15
# 4    2019    11418     11418/2019  01/12/2019 02:19:54  01/12/2019 04:23:47
# 5    2019    11418     11418/2019  01/12/2019 02:19:54  01/12/2019 04:23:47
# 6    2019    11418     11418/2019  01/12/2019 02:19:54  01/12/2019 04:23:47
# 7    2019    11418     11418/2019  01/12/2019 02:19:54  01/12/2019 04:23:47
# 8    2019    11418     11418/2019  01/12/2019 02:19:54  01/12/2019 04:23:47
# 9    2019    11418     11418/2019  01/12/2019 02:19:54  01/12/2019 04:23:47
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     30/11/2019          21:20          A NOITE      01/12/2019
# 1     29/11/2019          19:58          A NOITE      01/12/2019
# 2     30/11/2019          22:00          A NOITE      01/12/2019
# 3     01/12/2019            NaN     DE MADRUGADA      01/12/2019
# 4     01/12/2019          00:16     DE MADRUGADA      01/12/2019
# 5     01/12/2019          00:16     DE MADRUGADA      01/12/2019
# 6     01/12/2019          00:16     DE MADRUGADA      01/12/2019
# 7     01/12/2019          00:16     DE MADRUGADA      01/12/2019
# 8     01/12/2019          00:16     DE MADRUGADA      01/12/2019
# 9     01/12/2019          00:16     DE MADRUGADA      01/12/2019
#
#         DATAELABORACAO  ... PLACA_VEICULO UF_VEICULO   CIDADE_VEICULO  \
# 0  01/12/2019 00:45:32  ...       LAJ0710         SP        SÃO PAULO
# 1  01/12/2019 01:43:09  ...       NZV9018         SP        SÃO PAULO
# 2  01/12/2019 01:51:04  ...       DUG7217         SP        SÃO PAULO
# 3  01/12/2019 02:37:51  ...       DZU0078         SP        SAO PAULO
# 4  01/12/2019 02:19:54  ...           NaN        NaN              NaN
# 5  01/12/2019 02:19:54  ...       BHE3151         SP  ITAQUAQUECETUBA
# 6  01/12/2019 02:19:54  ...           NaN        NaN              NaN
# 7  01/12/2019 02:19:54  ...       BHE3151         SP  ITAQUAQUECETUBA
# 8  01/12/2019 02:19:54  ...           NaN        NaN              NaN
# 9  01/12/2019 02:19:54  ...       BHE3151         SP  ITAQUAQUECETUBA
#
#   DESCR_COR_VEICULO    DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0             Preta      IMP/GM CORSA WIND         1996.0        NaN
# 1             Preta   I/FORD FOCUS 2.0L FC         2012.0        NaN
# 2             Cinza  FIAT/STRADA FIRE FLEX         2006.0        NaN
# 3             Preta        YAMAHA/XTZ 125E         2008.0     2009.0
# 4               NaN                    NaN            0.0        0.0
# 5             Preta     FIAT/UNO ELETRONIC         1994.0     1994.0
# 6               NaN                    NaN            0.0        0.0
# 7             Preta     FIAT/UNO ELETRONIC         1994.0     1994.0
# 8               NaN                    NaN            0.0        0.0
# 9             Preta     FIAT/UNO ELETRONIC         1994.0     1994.0
#
#   DESCR_TIPO_VEICULO QUANT_CELULAR MARCA_CELULAR
# 0          AUTOMOVEL           NaN           NaN
# 1          AUTOMOVEL           NaN           NaN
# 2          AUTOMOVEL           NaN           NaN
# 3          MOTOCICLO           NaN           NaN
# 4                NaN           NaN           NaN
# 5          AUTOMOVEL           NaN           NaN
# 6                NaN           NaN           NaN
# 7          AUTOMOVEL           NaN           NaN
# 8                NaN           NaN           NaN
# 9          AUTOMOVEL           NaN           NaN
#
# [10 rows x 57 columns]

# %%
todos = pd.concat([jan, fev, mar, abr, mai, jun, jul, ago, sete, out,dez])

# %%
todos.head(10)
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2018    10437     10437/2018  31/12/2018 23:34:14  01/01/2019 00:04:01
# 1    2018    10437     10437/2018  31/12/2018 23:34:14  01/01/2019 00:04:01
# 2    2018    10437     10437/2018  31/12/2018 23:34:14  01/01/2019 00:04:01
# 3    2018  1650482   1650482/2018  01/01/2019 00:24:10  01/01/2019 00:24:06
# 4    2019        1         1/2019  01/01/2019 01:14:14  01/01/2019 01:27:46
# 5    2019       36        36/2019  01/01/2019 01:45:04  01/01/2019 01:45:11
# 6    2019       34        34/2019  01/01/2019 02:12:13  01/01/2019 02:12:23
# 7    2019      188       188/2019  01/01/2019 05:23:04  01/01/2019 05:23:10
# 8    2019        1         1/2019  01/01/2019 01:40:53  01/01/2019 06:55:49
# 9    2019       20        20/2019  01/01/2019 11:06:46  01/01/2019 11:06:46
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     31/12/2018            NaN          A NOITE      31/12/2018
# 1     31/12/2018            NaN          A NOITE      31/12/2018
# 2     31/12/2018            NaN          A NOITE      31/12/2018
# 3     31/12/2018          03:10     DE MADRUGADA      31/12/2018
# 4     31/12/2018          23:40          A NOITE      01/01/2019
# 5     31/12/2018          11:30       PELA MANHÃ      01/01/2019
# 6     31/12/2018          23:30          A NOITE      01/01/2019
# 7     01/01/2019          02:00     DE MADRUGADA      01/01/2019
# 8     31/12/2018          21:43          A NOITE      01/01/2019
# 9     31/12/2018          10:48  EM HORA INCERTA      31/12/2018
#
#         DATAELABORACAO  ... PLACA_VEICULO UF_VEICULO        CIDADE_VEICULO  \
# 0  31/12/2018 23:34:14  ...       DJI7167         SP             MAIRIPORA
# 1  31/12/2018 23:34:14  ...       DNZ8717         SP             MAIRIPORA
# 2  31/12/2018 23:34:14  ...       FLJ8259         SP             MAIRIPORA
# 3  01/01/2019 00:24:10  ...       CMC4652         SP        RIBEIRÃO PIRES
# 4  01/01/2019 01:14:14  ...       ECR3583         SP              PRATANIA
# 5  01/01/2019 01:45:04  ...       BND 839         SP  SÃO BERNARDO DO CAMP
# 6  01/01/2019 02:12:13  ...       BVY3028         SP       TABOÃO DA SERRA
# 7  01/01/2019 05:23:04  ...       CDK7498         SP  SÃO BERNARDO DO CAMP
# 8  01/01/2019 01:40:53  ...       DNC5921         SP                SUZANO
# 9  01/01/2019 11:06:46  ...       BMY1122         SP             GUARULHOS
#
#   DESCR_COR_VEICULO       DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0             Preta     HONDA/CG 125 TITAN KS         2003.0     2004.0
# 1             Preta               VW/CROSSFOX         2005.0     2005.0
# 2          Vermelho             HONDA/XRE 300         2016.0     2016.0
# 3          Vermelho            FIAT/PALIO EDX         1998.0        NaN
# 4            Branco       KASINSKI/CRZ 150 10         2011.0     2011.0
# 5            Branco              GM/CHEVY 500         1993.0        NaN
# 6          Vermelho              GM/KADETT GL         1994.0        NaN
# 7             Cinza          IMP/FIAT UNO I.E         1996.0        NaN
# 8             Preta    HONDA/CG 150 TITAN ESD         2005.0     2005.0
# 9            Branco  Y/YAMAHA XT 600 Z TENERE         1992.0     1992.0
#
#   DESCR_TIPO_VEICULO QUANT_CELULAR MARCA_CELULAR
# 0          MOTOCICLO           NaN           NaN
# 1          AUTOMOVEL           NaN           NaN
# 2          MOTOCICLO           NaN           NaN
# 3          AUTOMOVEL           NaN           NaN
# 4          MOTOCICLO           NaN           NaN
# 5          AUTOMOVEL           NaN           NaN
# 6          AUTOMOVEL           NaN           NaN
# 7          AUTOMOVEL           NaN           NaN
# 8          MOTOCICLO           NaN           NaN
# 9          MOTOCICLO           NaN           NaN
#
# [10 rows x 57 columns]

# %%
todos.drop_duplicates(subset ="NUM_BO", keep = False, inplace = True)

# %%
todos = todos.drop(['NUM_BO', 'NUMERO_BOLETIM', 'PLACA_VEICULO', 'UF_VEICULO', 'CIDADE_VEICULO', 'MARCA_CELULAR', 'IDADE', 'SEXO', 'TIPOPESSOA', 'STATUS', 'DESDOBRAMENTO', 'FLAGRANTE', 'DESCRICAOLOCAL', 'QUANT_CELULAR', 'BO_AUTORIA', 'NUMERO_BOLETIM_PRINCIPAL', 'EXAME', 'SOLUCAO', 'NOMEPESSOA', 'VITIMAFATAL', 'RG', 'RG_UF', 'NATURALIDADE', 'NACIONALIDADE', 'DATANASCIMENTO', 'ESTADOCIVIL', 'PROFISSAO', 
'GRAUINSTRUCAO', 'CORCUTIS', 'NATUREZAVINCULADA', 'TIPOVINCULO', 'RELACIONAMENTO', 'PARENTESCO'], axis = 1)

# %%
todos = todos.drop(['DELEGACIA_NOME', 'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA'], axis = 1)

# %%
for col in todos:
    print(col)
# Out:
# ANO_BO
# BO_INICIADO
# BO_EMITIDO
# DATAOCORRENCIA
# HORAOCORRENCIA
# PERIDOOCORRENCIA
# DATACOMUNICACAO
# DATAELABORACAO
# LOGRADOURO
# NUMERO
# BAIRRO
# CIDADE
# UF
# LATITUDE
# LONGITUDE
# DESCR_COR_VEICULO
# DESCR_MARCA_VEICULO
# ANO_FABRICACAO
# ANO_MODELO
# DESCR_TIPO_VEICULO

# %%
todos.dtypes
# Out:
# ANO_BO                   int64
# BO_INICIADO             object
# BO_EMITIDO              object
# DATAOCORRENCIA          object
# HORAOCORRENCIA          object
# PERIDOOCORRENCIA        object
# DATACOMUNICACAO         object
# DATAELABORACAO          object
# LOGRADOURO              object
# NUMERO                   int64
# BAIRRO                  object
# CIDADE                  object
# UF                      object
# LATITUDE                object
# LONGITUDE               object
# DESCR_COR_VEICULO       object
# DESCR_MARCA_VEICULO     object
# ANO_FABRICACAO         float64
# ANO_MODELO             float64
# DESCR_TIPO_VEICULO      object
# dtype: object

# %%
todos.to_csv('DADOS/furtos_metro_2019.csv', index = False)
